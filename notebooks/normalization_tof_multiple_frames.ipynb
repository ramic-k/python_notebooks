# %% [markdown]
# <img src='__docs/__all/notebook_rules.png' />

# %% [markdown]
# # Multi-frame TOF normalization planner
#
# Configure each wavelength frame independently, inspect rebinned ROI transmission in the common energy overlap, then launch the full normalization only after the recipe is settled.

# %%
from __code import system
from __code.__all import custom_style
from __code.normalization_tof.multiple_frames_ui import MultiFrameNormalizationTof

system.System.select_working_dir(
    notebook='normalization',
    instrument='VENUS',
    ipts='IPTS-35167',
    instrument_to_exclude=['CG1D'],
)
custom_style.style()
# Out:
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
#                        <style>
#                        .result_label {
#                           font-style: bold;
#                           color: red;
#                           font-size: 18px;
#                        }
#                        </style>
# ...
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# ...

# %%
o_multiframe = MultiFrameNormalizationTof(
    working_dir=(
        f'/SNS/{system.System.get_instrument_selected()}/'
        f'IPTS-{system.System.get_ipts_selected()}'
    )
)
o_multiframe.display()
